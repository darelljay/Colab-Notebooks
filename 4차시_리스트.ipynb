# %% [markdown]
# # 2.1 리스트의 생성 인덱싱 수정 제거하기

# %% [markdown]
# 리스트(list)는

# %% [markdown]
# 1. 여러개의 객체를 원소로 담을 수 있는 컨테이너 자료형(Container Data-type)이다.
# 2. 구성하는 원소들(Elements)에 순서가 있다.
# 3. 리스트를 구성하는 원소를 바꿀 수 있다.

# %% [markdown]
# ## 1) 리스트 생성하기

# %%
# 비어있는 리스트를 생성
lst0 = 
lst0
# Out:
# []

# %%
# 여러개의 숫자들을 저장
lst1 = 
lst1
# Out:
# [1, 3, 5, 7, 9]

# %%
# 정수 이외의 실수나 텍스트도 담는다면
lst2 = 
lst3 = 
lst2
#lst3
# Out:
# []

# %%
# 리스트 내에 리스트 또는 변수를 담는다면
n1 = 100
lst3 = []
lst3
# Out:
# []

# %% [markdown]
# ## 2) 리스트(list) 다루기 기본

# %% [markdown]
# 리스트(list)에서 원소의 가져오기, 수정하기, 추가하기, 제거하기

# %% [markdown]
# **리스트를 구성하는 원소 가져오기**

# %%
a = [1,2,3,4,5]
a
# Out:
# [1, 2, 3, 4, 5]

# %%
# a 리스트의 첫번째 위치의 값 얻기
element_2 = a[0]
element_2
# Out:
# 1

# %%
# 리스트의 마지막 값 얻기
element_3 = 
element_3
# Out:
# 5

# %%
# 리스트의 범위를 지정하여 값 얻기 ..[2,3] 출력
elememt_3 = 
elememt_3
# Out:
# [2, 3]

# %%
# 리스트의 세번째 이후 값 얻기   [3,4,5]
element_4 =
element_4
# Out:
# [3, 4, 5]

# %%
# 리스트의 범위에서 step으로 건너뛰며 값 얻기  [1,3,5]
element_5 = 
element_5
# Out:
# [1, 3, 5]

# %% [markdown]
# **리스트의 특정 원소 확인하기**

# %%
lst = [1,2,3]

# %%
# 리스트에 요소 추가 ( 리스트 + 리스트)   결과값 [1,2,3,4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
# 멤버연산자 ( 해당 값이 리스트 안에 있을경우 in  없을 경우 not in)
# Out:
# True

# %% [markdown]
# **리스트의 특정 원소 수정하기**

# %%
# 리스트의 특정 위치의 값을 수정하기

# %% [markdown]
# **리스트에 새로운 원소 추가하기**

# %%
a = [1,2,3]
# 리스트의 가장 뒤에 값 추가하기 (append)

# %%
# 리스트의 가장 뒤에 리스트를 원소로 추가하기 (append)

# %%
# 리스트의 가장 뒤에 리스트로 이뤄진 값 추가하기(extend)

# %%
# 리스트의 특정 위치에 특정 값 추가하기 insert(인덱스, 값)

# %% [markdown]
# **리스트의 특정 원소 제거하기**

# %%
a = [1,2,3]
# 특정 위치의 값 제거   del 리스트명[index]

# %%
# 특정 항목값 제거    리스트명.remove(값)

# %%
# 가장 마지막 원소을 반환하고, 해당 원소는 리스트에서 제거하기  리스트명.pop(index)

# %%
#모든 요소 제거      리스트명.clear()
# Out:
# []

# %%
# 해당 값이 리스트 안에 없을 경우
lst = [1,2,3,4,5]

#lst.remove(6)
#del lst[5]
lst

lst = []
lst.pop()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-34-e615429c5a53> in <module>()
#       7
#       8 lst = []
# ----> 9 lst.pop()
#
# IndexError: pop from empty list

# %% [markdown]
# 연습 문제

# %% [markdown]
# ## 리스트 함수들

# %% [markdown]
# ## 리스트 정렬

# %% [markdown]
# ## 리스트 뒤집기

# %% [markdown]
# ## split 함수

# %% [markdown]
# ## join함수
