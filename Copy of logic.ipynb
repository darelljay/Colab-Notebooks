# %%
#논리를 표현하는 기법
# 반복 , 선택 , 알고리즘

# %%
print("유미선 \n"*5);
# Out:
# 유미선
# 유미선
# 유미선
# 유미선
# 유미선

# %%
for i in range(5):
  print(i+1,".유미선")
print("End")
# Out:
# 1 .유미선
# 2 .유미선
# 3 .유미선
# 4 .유미선
# 5 .유미선
# End

# %%
range(5)
ls = list(range(10,101,10))

# %%
ls
# Out:
# [10]

# %%
ls = list(range(10,0,-2))

# %%
ls
# Out:
# [10, 8, 6, 4, 2]
