# %%
month = 4
day = 4
print(f'2022년{month}월,{day}일')
# Out:
# 2022년4월,4일

# %%
age = 17
name = 'darell'
print("제 나이는 %d 살 %s 입니다"%(age, name))
# Out:
# 제 나이는 17 살 darell 입니다

# %%
box= 6
apple = 175


print("상자는",173//25,"상자","바구니에는",173%25,"입니다")
# Out:
# 상자는 6 상자 바구니에는 23 입니다

# %%
a = 10
b = 10
c = 20
v = a*b*c

print("직육면체의 부피는",v,"입니다")
# Out:
# 직육면체의 부피는 2000 입니다

# %%
print("네가 생각한답은",2360*102/240+490-82,"이야!")
# Out:
# 네가 생각한답은 1411.0 이야!

# %%
2<3
True

10>23
False
# Out:
# False

# %%
multiline="""life is too short 
you need python"""
print(multiline)
# Out:
# life is too short
# you need python

# %%
name= """송:송혜교보다 아름답고
은: 은쟁반에 옥구슬 굴러가는 아름다운 목소리
이:이효리"""
print(name)
# Out:
# 송:송혜교보다 아름답고
# 은: 은쟁반에 옥구슬 굴러가는 아름다운 목소리
# 이:이효리

# %%
a = "사랑해"
a*1000
# Out:
# '사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사랑해사
# ...

# %%
head = "python"
tail = " is fun!"
head + tail
# Out:
# 'python is fun!'

# %%
a,b = 10,"20"
print(a+int(b))
# Out:
# 30

# %%
a,b = 10,"20"
print(str(a)+b)
# Out:
# 1020

# %%
a,b = 10,20
print(float(a)+float(b))
# Out:
# 30.0

# %%
name = input("이름을 입력하세요")
print("안녕하세요",name,"님 반갑습니다.")
# Out:
# 이름을 입력하세요다렐
# 안녕하세요 다렐 님 반갑습니다.

# %%
age = input("나이를 입력하세요")
type(age)
print(type(age),age,int(age))
# Out:
# 나이를 입력하세요17
# <class 'str'> 17 17

# %%
name = input("이름을 입력하세요")
age = input("나이를 입력하세요")
print("이름은",name,"이시고 나이는",age,"살 이군요")
# Out:
# 이름을 입력하세요다렐
# 나이를 입력하세요17
# 이름은 다렐 이시고 나이는 17 살 이군요

# %%
num1 = int(input("숫자를 입력하세요"))
type (num1)
# Out:
# 숫자를 입력하세요1234
# int

# %%
name = input('이름:')
age = int(input('나이:'))
height = float(input("키:"))
weight = float(input('몸무게:'))
print(name,age,height,weight)
# Out:
# 이름:다렐
# 나이:17
# 키:181
# 몸무게:8903120
# 다렐 17 181.0 8903120.0

# %%
 f = float(input('화씨온도: '))
 c = (f-32)*5/9
 print("섭씨온도: %.1f"%c)
# Out:
# 화씨온도: 100
# 섭씨온도: 37.8

# %%
a = "life is too short,you need python"
a[9]
# Out:
# 'o'

# %%
a = "life is too short,you need python"
a[-9]
# Out:
# 'e'

# %%
a = input("정수: ")

print("자릿수의 합: ",int(a[0])+int(a[1])+int(a[2])+int(a[3]))
# Out:
# 정수: 1234
# 자릿수의 합:  10

# %%
a = "life is too short, you need python"
a[0:4]
# Out:
# 'life'

# %%
a = "life is too short, you need python"
a[8:11]
# Out:
# 'too'

# %%
name =input("영문이름: ")
pwd = name[:2]+name[-2:]
pwd = pwd[::-1]
print(pwd)
# Out:
# 영문이름: python
# noyp
