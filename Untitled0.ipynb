# %%
import math
a = int(input())
b = int(input())
print(a**b)
print(math.sqrt(2))
# Out:
# 13
# 31
# 34059943367449284484947168626829637
# 1.4142135623730951

# %%
a = int(input())
b = int(input())
print(a**b)
# Out:
# 2
# 10
# 1024

# %%
a = int(input())
b = int(input())
def squard(number1, number2):
  print(number1 + number2)
squard(a, b)
def squard(number1, number2):
  print(number1 - number2)
squard(a, b)
def squard(number1, number2):
  print(number1 * number2)
squard(a, b)
def squard(number1, number2):
  print(number1 / number2)
squard(a, b)
# Out:
# 3
# 5
# 8
# -2
# 15
# 0.6
