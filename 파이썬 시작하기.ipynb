# %%
4+5
# Out:
# 9

# %%
 a = "python"
 print(a)
# Out:
# python

# %%
print('고양이는','야옹');
# Out:
# 고양이는 야옹

# %%
a = 8*9/72

print(a)
# Out:
# 1.0

# %%
print(1+2) #3
print(2>3) #True
print(2<3) #False
# Out:
# 3
# False
# True

# %%
print("hello,world")
print("1더하기 2는", 1+2  )
age = 10;
print("나는 ",age,"살 입니다.")
# Out:
# hello,world
# 1더하기 2는 3
# 나는  10 살 입니다.

# %%
print("hello", end="");
print("world")
print()
# Out:
# helloworld

# %%
# she said what you go do if  i leav i said bitch imma do me b.ig bitch everything zoomed in b.i.g  on me looking like im mooving in got a\my foot in and im still here im a first generation maillionare broke that curse in my family im pationate like girls are just mor than after chash and dick.

# %%
myName = "파이썬"
type(myName)

myNum = 45
type(myNum)
# Out:
# int

# %%
a =3*2-8/4
b = 25*6/3+16
print(a)
print(b)
# Out:
# 4.0
# 66.0

# %%
a = 5
print("현변의 길이가 5인 정사각형의 넓이는",a*a,"입니다")
# Out:
# 현변의 길이가 5인 정사각형의 넓이는 25 입니다
