# %% [markdown]
# # 딕셔너리(Dictionary)

# %% [markdown]
# ---

# %% [markdown]
# 1. 여러개의 객체를 원소로 담을 수 있는 컨테이너 자료형(Container Data-type)이다.
# 2. 키(key)와 값(value)를 한 쌍으로 갖는다.
# 3. 구성하는 원소들에 순서가 없다.
# 4. 구성하는 키의 중복을 허용하지 않는다.

# %% [markdown]
# ##  딕셔너리 생성하기

# %%
# 비어있는 dict0를 생성

# %%
# 여러개의 key와 value들을 저장

# %% [markdown]
# ## 딕셔너리를 구성하는 원소 가져오기

# %% [markdown]
# ## 딕셔너리의 원소를 추가하거나 수정하기

# %% [markdown]
# ##  딕셔너리의 특정 원소 제거하기

# %% [markdown]
# ## 딕셔너리(dict)의 함수

# %%
scores = {'kor':70,'end':89,'math':95,'music':100 }

# %%
#키만 추출하기

# %%
#값만 추출하기

# %%
#키:값 형태의 항목 모두 추출하기

# %%
#for 문 이용
# Out:
# ('kor', 70)
# ('end', 89)
# ('math', 95)
# ('music', 100)

# %% [markdown]
# ![요금표.png](data:image/png;base64,...)
#
# 입력 받은 승객 구분에 따라 요금을 출력하세요 ( 딕셔너리 사용 )
#
# 구분 : 어린이

# %%
# Out:
# 구분어린이
# 요금은 500 입니다
