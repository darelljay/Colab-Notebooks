# %%
a = float(input("구의 반지름을 입력하세요"))
b = (4/3)*3.141592*(a**3)
c = 4*3.141592*a**2
print(b)
print(c)
# Out:
# 구의 반지름을 입력하세요5
# 523.5986666666666
# 314.1592

# %%
num = int(input("정수입력: "))
if(num%2==0):
  print("짝수입니다")
else:
    print("홀수입니다")
# Out:
# 정수입력: 0
# 짝수입니다

# %%
import datetime

now = datetime.datetime.now()
month = now.month

if 3<=month <=5:
  print("현재는 봄입니다.")
elif 6<=month<=8:
  print("현재는 여름입니다.")
elif 9<= month <= 11:
  print("현재는 가을입니다.")
else:
  print("현재는 겨울입니다")
# Out:
# 현재는 여름입니다.

# %%
score = float(input("학점을 입력해주세요"))

if score==4.5:
  print("신")
elif score>=4.2 and score<4.5:
  print("교수님의 사랑") 
elif score>=3.5 and score<4.2:
  print("현체제의 수호자")
elif score>=2.8 and score<3.5:
  print("일반인") 
elif score>=2.3 and score<2.8:
  print("일탈을 꿈꾸는 소시민")
elif score>=1.75 and score<2.3:
  print("오락문화의 선구자") 
elif score>=1.0 and score<1.75:
  print("불가촉천민")
elif score>=0.5 and score<1.0:
  print("자벌레")
elif score>0 and score<0.5:
  print("플랑크톤") 
elif socre==0:
  print("시대를 앞서가는 혁명의 씨앗")
# Out:
# 학점을 입력해주세요3.4
# 일반인

# %%
year = int(input("태어난 해를 입력해주세요"))
if year%12==0:
  print("원숭이")
elif year%12==1:
  print("닭")
elif year%12==2:
  print("개")
elif year%12==3:
  print("돼지")
elif year%12==4:
  print("쥐")
elif year%12==5:
  print("소")
elif year%12==6:
  print("범")
elif year%12==7:
  print("토끼")
elif year%12==8:
  print("용")
elif year%12==9:
  print("뱀")
elif year("말"):
  print("양")
# Out:
# 태어난 해를 입력해주세요1892
# 용

# %%
import datetime
now = datetime.datetime.now()
ai = input(" ")
if ai =="안녕":
  print("안녕하세요")
elif ai == "지금 몇시야?" or "지금 몇시에요?":
  print(now.time())
# Out:
#  지금 몇시야?
# 06:49:27.689707
