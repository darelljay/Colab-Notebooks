# %% [markdown]
# # 함수 (function) - 어떤 기능을 수행하는 프로그램 코드

# %% [markdown]
# #함수의 종류
#
# ##함수의 종류
# ###1)내장 함수
#
# 함수의 기능이 파이썬 자체에 내장되어 있는 함수
#
# print(), input(), int(), str(), len(), append(), remove() 등
# ###2)사용자 함수
# 사용자가 직접 만들어서 사용하는 함수

# %% [markdown]
# ##함수의 정의와 호출

# %%
def hello():
  print('hello!!!')
hello()

# %% [markdown]
# ### 1) 함수의 구조

# %% [markdown]
# 함수를 이용하여 어떤 수가 짝수인지 홀수인지를 판별하는 프로그램
#
# def even_odd(n) :

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2) 함수의 활용
# 삼각형의 밑변과 높이를 입력 받아 함수를 이용하여 삼각형의 면적을 구하는 프로그램
#
# def triangle(a, b) :

# %%
def triangle():
  height = int(input('높이를 입력하세요'))
  base = int(input('밑변을 입력하세요'))
  print((height*base)/2)
triangle()
# Out:
# 높이를 입력하세요20
# 밑변을 입력하세요55
# 550.0

# %% [markdown]
# ###3) 함수로 정수 합계 구하기 (정수 start부터 end까지의 합)
#
# def total(start, end) :

# %%
def total(start,end):
  sum=0
  for start in range(end):
    sum+=start
  print(sum)
total(1,11)
# Out:
# 55

# %% [markdown]
# ###4) x,y 좌표를 입력 받아 그 지점이 몇 사분면에 있는지를 판단하는 프로그램을 작성해보세요~
#
# ![image.png](data:image/png;base64,...)
#
# def find(x, y):

# %%
def find(x,y):
  if x>0 and y>0:
    print('제 1사분면')
  elif x<0 and y>0:
      print('제 2사분면')
  elif x<0 and y<0:
      print('제 3사분면')
  else:
      print('제 4사분면')
find(10,20)
# Out:
# 제 1사분면
