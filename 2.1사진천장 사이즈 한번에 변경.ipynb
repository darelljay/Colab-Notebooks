# %% [markdown]
# #파이썬 기술 살펴보기

# %% [markdown]
# PIL open

# %%
from PIL import Image
a = Image.open("cat.jpg")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-b407fcf2a6b9> in <module>
#       1 from PIL import Image
# ----> 2 a = Image.open("cat.jpg")
#
# /usr/local/lib/python3.8/dist-packages/PIL/Image.py in open(fp, mode)
#    2841
#    2842     if filename:
# -> 2843         fp = builtins.open(filename, "rb")
#    2844         exclusive_fp = True
#    2845
#
# FileNotFoundError: [Errno 2] No such file or directory: 'cat.jpg'

# %% [markdown]
# # 새 섹션

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %% [markdown]
# image size

# %%
a.size

# %%
x,y = a.size

# %%
x

# %%
y

# %% [markdown]
# resize

# %%
a.resize((200,300))

# %%
a

# %%
b = a.resize((200,300))

# %%
b.size

# %% [markdown]
# save

# %%
b,save("test")
b.close
